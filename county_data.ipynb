# %%
import pandas as pd

# %%
county_data = pd.read_csv('County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')

# %%
dates = county_data.columns[9:] # These are the timestamps
price_by_county = pd.DataFrame(county_data[dates].values.T, columns=county_data['RegionName'], index=dates) # Transposing the dataset, now using the RegionName (ZIP code) as the columns, dates for the index, and transposing the housing data
price_by_county
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     county        CA    CA
# 1          139         1         Cook County     county        IL    IL
# 2         1090         2       Harris County     county        TX    TX
# 3         2402         3     Maricopa County     county        AZ    AZ
# 4         2841         4    San Diego County     county        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 3068       846      3206       Banner County     county        NE    NE
# 3069      1648      3207      Daggett County     county        UT    UT
# 3070      1432      3208       Thomas County     county        NE    NE
# 3071      2794      3212    McPherson County     county        NE    NE
# 3072      2825      3214    Petroleum County     county        MT    MT
#
#                                      Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# ...
