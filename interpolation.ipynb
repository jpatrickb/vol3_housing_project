# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d, LinearNDInterpolator

# %%
import data_loader

data = data_loader.load_data()

# %%
data.loc['California']['Median Home Price'].plot()
plt.show()

# %%
plt.plot(data.loc['California']['Median Home Price'].pct_change().values[1:], label='pct change')
plt.plot(np.diff(np.log(data.loc['California']['Median Home Price'])), label='log diff')
plt.legend()
plt.show()
